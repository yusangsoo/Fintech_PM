# %% [markdown]
# ## db에서 상장기업정보를 받아 네이버 증권에서 주가 수집하기

# %%
import os
import pandas as pd
from datetime import date
from dotenv import load_dotenv
from sqlalchemy import create_engine
import pymysql
import time
import requests
from bs4 import BeautifulSoup

# %%
pymysql.install_as_MySQLdb()
load_dotenv(dotenv_path = ".env_db")
# Out:
# True

# %%
# mysql에서 테이블 불러오기
engine = create_engine(f"{os.getenv('db')}+{os.getenv('dbtype')}://{os.getenv('id')}:{os.getenv('pw')}@{os.getenv('host')}/{os.getenv('db_name')}")
conn = engine.connect()
data = pd.read_sql('stock_company_info_2024_07_29', con = conn)
conn.close()

# %%
data
# Out:
#                                 증권종류    종목코드            회사명  \
# 0                               유가증권  062040          산일전기
# 1                               유가증권  487570       에이치에스효성
# 2                        코스닥, 투자주의종목  481890    엔에이치스팩31호
# 3                                코스닥  473950    SK증권제13호스팩
# 4                                코스닥  373110       엑셀세라퓨틱스
# ...                              ...     ...            ...
# 2700  유가증권, KTOP30, KOSPI200, KRX300  000100       유한양행
# 2701          유가증권, KOSPI200, KRX300  000120      CJ대한통운
# 2702                            유가증권  000050            경방
# 2703                            유가증권  000700         유수홀딩스
# 2704                            유가증권  003480      한진중공업홀딩스
#
#                                      업종  \
# 0     전동기, 발전기 및 전기 변환 · 공급 · 제어 장치 제조업
# 1                                기타 금융업
# 2                            금융 지원 서비스업
# 3                            금융 지원 서비스업
# 4                           기초 의약물질 제조업
# ...

# %%
for code in data['종목코드'] :
    url = f'https://finance.naver.com/item/main.naver?code={code}'
    print(url)
# Out:
# https://finance.naver.com/item/main.naver?code=062040
# https://finance.naver.com/item/main.naver?code=487570
# https://finance.naver.com/item/main.naver?code=481890
# https://finance.naver.com/item/main.naver?code=473950
# https://finance.naver.com/item/main.naver?code=373110
# https://finance.naver.com/item/main.naver?code=478110
# https://finance.naver.com/item/main.naver?code=462870
# https://finance.naver.com/item/main.naver?code=450330
# https://finance.naver.com/item/main.naver?code=462350
# https://finance.naver.com/item/main.naver?code=481850
# https://finance.naver.com/item/main.naver?code=295310
# https://finance.naver.com/item/main.naver?code=266350
# https://finance.naver.com/item/main.naver?code=160190
# https://finance.naver.com/item/main.naver?code=479880
# https://finance.naver.com/item/main.naver?code=464080
# https://finance.naver.com/item/main.naver?code=478440
# https://finance.naver.com/item/main.naver?code=477340
# ...

# %%
url = "https://finance.naver.com/item/main.naver?code=009450"

r = requests.get(url)
dataset = r.text
soup2 = BeautifulSoup(dataset, 'lxml')
soup2
# Out:
# <html lang="ko">
# <head>
# <title>경동나비엔 : 네이버페이 증권</title>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="text/javascript" http-equiv="Content-Script-Type"/>
# <meta content="text/css" http-equiv="Content-Style-Type"/>
# <meta content="네이버페이 증권" name="apple-mobile-web-app-title"/>
# <meta content="https://finance.naver.com/item/main.naver?code=009450" property="og:url"/>
# <meta content="경동나비엔 - 네이버페이 증권 : 네이버페이 증권" property="og:title"/>
# <meta content="관심종목의 실시간 주가를 가장 빠르게 확인하는 곳" property="og:description"/>
# <meta content="https://ssl.pstatic.net/static/m/stock/im/2016/08/og_stock-200.png" property="og:image"/>
# <meta content="article" property="og:type"/>
# <meta content="" property="og:article:thumbnailUrl"/>
# <meta content="네이버페이 증권" property="og:article:author"/>
# <meta content="http://FINANCE.NAVER.COM" property="og:article:author:url"/>
# ...

# %%
# 회사명
soup.select_one('h2 > a').string
# Out:
# '경동나비엔'

# %%
# 년월일은 today로 하면 됨
# 종목코드는 이미 갖고 있으니 하면 됨

# %%
soup.select_one('.rate_info')
# Out:
# <div class="rate_info">
# <dl class="blind">
# <dt><strong>경동나비엔</strong></dt>
# <dd>오늘의시세 58,100 포인트</dd>
# <dd>700 포인트 상승</dd>
# <dd>1.22% 플러스</dd>
# </dl>
# <div class="today">
# <p class="no_today">
# <em class="no_up">
# <span class="blind">58,100</span>
# <span class="no5">5</span><span class="no8">8</span><span class="shim">,</span><span class="no1">1</span><span class="no0">0</span><span class="no0">0</span>
# </em>
# </p>
# <p class="no_exday">
# <span class="sptxt sp_txt1">전일대비</span>
# <em class="no_up">
# <span class="ico up">상승</span>
# <span class="blind">700</span>
# <span class="no7">7</span><span class="no0">0</span><span class="no0">0</span>
# </em>
# <span class="bar">l</span>
# <em class="no_up">
# <span class="ico plus">+</span>
# <span class="blind">1.22</span>
# <span class="no1">1</span><span class="jum">.</span><span class="no2">2</span><span class="no2">2</span>
# <span class="per">%</span>
# </em>
# </p>
# </div>
# ...

# %%
soup.select('.rate_info  span.blind')
# Out:
# [<span class="blind">58,100</span>,
#  <span class="blind">700</span>,
#  <span class="blind">1.22</span>,
#  <span class="blind">57,400</span>,
#  <span class="blind">58,800</span>,
#  <span class="blind">74,600</span>,
#  <span class="blind">40,581</span>,
#  <span class="blind">57,500</span>,
#  <span class="blind">57,400</span>,
#  <span class="blind">2,354</span>]

# %%
# 첫번째는 현재가
# 두번째는 변동가
# 세번째는 변동률
# 4번째는 전일가
# 5번째는 고가
# 6번째는 상한가
# 7번째는 거래량
# 8번째는 시가
# 9번째는 저가
# 10번째는 거래대금

# %%
for i in soup.select('.rate_info span.blind') :
    print(i.string)
# Out:
# 58,500
# 1,100
# 1.92
# 57,400
# 58,800
# 74,600
# 36,180
# 57,500
# 57,400
# 2,097

# %%
# 2개 종목만
stock = {}
for code in data['종목코드'][:2] :
    url = f'https://finance.naver.com/item/main.naver?code={code}'
    r = requests.get(url)
    dataset = r.text
    soup = BeautifulSoup(dataset, 'lxml')
    today = str(date.today())
    # 년월일
    stock.setdefault("년월일", []).append(today)
    
    # 회사명
    stock.setdefault("회사명",[]).append(soup.select('dl.blind > dd')[1].string.split(" ")[1])
    
    # 종목코드
    stock.setdefault("종목코드", []).append(f"{code}")
    
    # 현재가
    stock.setdefault("현재가",[]).append(soup.select('.rate_info  span.blind')[0].string.replace(",",""))
    
    # 변동금액
    stock.setdefault("변동금액",[]).append(soup.select('.rate_info  span.blind')[1].string.replace(",",""))
    
    # 변동률
    stock.setdefault("변동률",[]).append(soup.select('.rate_info  span.blind')[2].string.replace(",",""))
    
    # 전일
    stock.setdefault("전일",[]).append(soup.select('.rate_info  span.blind')[3].string.replace(",",""))
    
    # 고가
    stock.setdefault("고가",[]).append(soup.select('.rate_info  span.blind')[4].string.replace(",",""))
    
    # 거래량
    stock.setdefault("거래량",[]).append(soup.select('.rate_info  span.blind')[6].string.replace(",",""))
    
    # 시가
    stock.setdefault("시가",[]).append(soup.select('.rate_info  span.blind')[7].string.replace(",",""))
    
    # 저가
    stock.setdefault("저가",[]).append(soup.select('.rate_info  span.blind')[8].string.replace(",",""))
    
    # 거래대금
    stock.setdefault("거래대금",[]).append(soup.select('.rate_info  span.blind')[9].string.replace(",",""))
    
    
df = pd.DataFrame(stock)
df
# Out:
#           년월일      회사명    종목코드    현재가   변동금액    변동률      전일      고가       거래량  \
# 0  2024-07-29     산일전기  062040  50200  15200  43.43   35000   50200  17064042
# 1  2024-07-29  에이치에스효성  487570  82600  35400  30.00  118000  118000    314451
#
#        시가     저가    거래대금
# 0   44900  40200  761243
# 1  118000  82600   28370

# %%
# 첫번째는 현재가
# 두번째는 변동가
# 세번째는 변동률
# 변동률은 +랑 -도 가져왔어야 함.
# 하는 법은 쉬움... +랑 -랑 각자 가져오고 값이랑 합치면 됨...
# 4번째는 전일가
# 5번째는 고가
# 6번째는 상한가
# 7번째는 거래량
# 8번째는 시가
# 9번째는 저가
# 10번째는 거래대금

# %%
# 전체 종목
stock = {}
for i, code in enumerate(data['종목코드']) :
    url = f'https://finance.naver.com/item/main.naver?code={code}'
    r = requests.get(url)
    dataset = r.text
    soup = BeautifulSoup(dataset, 'lxml')
    today = str(date.today())
    if code[0] in ("U", "S", "J", "H","C") :
        continue
    else :
        # 년월일
        stock.setdefault("년월일", []).append(today)

        # 회사명
        stock.setdefault("회사명",[]).append(soup.select('dl.blind > dd')[1].string.split(" ")[1])

        # 종목코드
        stock.setdefault("종목코드", []).append(f"{code}")

        # 현재가
        stock.setdefault("현재가",[]).append(soup.select('.rate_info  span.blind')[0].string.replace(",",""))

        # 변동금액
        stock.setdefault("변동금액",[]).append(soup.select('.rate_info  span.blind')[1].string.replace(",",""))
        
        # 변동률
        if soup.select('.rate_info span.blind')[2].string == '0.00' :
            stock.setdefault("변동률",[]).append(soup.select('.rate_info span.blind')[2].string)
        elif soup.select('.rate_info dd')[2].string[-3:] == "플러스" :
            stock.setdefault("변동률",[]).append(float(soup.select_one('.rate_info span.ico.plus').text+soup.select('.rate_info span.blind')[2].string))
        else :
            stock.setdefault("변동률",[]).append(float(soup.select_one('.rate_info span.ico.minus').text+soup.select('.rate_info span.blind')[2].string))

        # 전일
        stock.setdefault("전일",[]).append(soup.select('.rate_info  span.blind')[3].string.replace(",",""))

        # 고가
        stock.setdefault("고가",[]).append(soup.select('.rate_info  span.blind')[4].string.replace(",",""))

        # 거래량
        stock.setdefault("거래량",[]).append(soup.select('.rate_info  span.blind')[6].string.replace(",",""))

        # 시가
        stock.setdefault("시가",[]).append(soup.select('.rate_info  span.blind')[7].string.replace(",",""))

        # 저가
        stock.setdefault("저가",[]).append(soup.select('.rate_info  span.blind')[8].string.replace(",",""))

        # 거래대금
        stock.setdefault("거래대금",[]).append(soup.select('.rate_info  span.blind')[9].string.replace(",",""))

        time.sleep(3)
        print(f'{i}번째 진행 중',code, end = "\r")
df = pd.DataFrame(stock)
df
# Out:
# 877번째 진행 중 063760
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[271], line 53
#      50         # 거래대금
#      51         stock.setdefault("거래대금",[]).append(soup.select('.rate_info  span.blind')[9].string.replace(",",""))
# ---> 53         time.sleep(3)
#      54         print(f'{i}번째 진행 중',code, end = "\r")
#      55 df = pd.DataFrame(stock)
#
# KeyboardInterrupt:

# %%
# 오류 찾음
data['종목코드'][454]
# Out:
# 'USA140'

# %%
# 오류 해결
# 2개 종목만
stock = {}
for code in data['종목코드'][456:458] :
    url = f'https://finance.naver.com/item/main.naver?code={code}'
    r = requests.get(url)
    dataset = r.text
    soup = BeautifulSoup(dataset, 'lxml')
    today = str(date.today()) 
    if code[0] in ("U", "S", "J", "H","C") :
        continue
    else :
        # 년월일
        stock.setdefault("년월일", []).append(today)

        # 회사명
        stock.setdefault("회사명",[]).append(soup.select('dl.blind > dd')[1].string.split(" ")[1])

        # 종목코드
        stock.setdefault("종목코드", []).append(f"{code}")

        # 현재가
        stock.setdefault("현재가",[]).append(int(soup.select('.rate_info  span.blind')[0].string.replace(",","")))

        # 변동금액
        stock.setdefault("변동금액",[]).append(int(soup.select('.rate_info  span.blind')[1].string.replace(",","")))

        # 변동률
        if soup.select('.rate_info span.blind')[2].string == '0.00' :
            stock.setdefault("변동률",[]).append(soup.select('.rate_info span.blind')[2].string)
        elif soup.select('.rate_info dd')[2].string[-3:] == "플러스" :
            stock.setdefault("변동률",[]).append(float(soup.select_one('.rate_info span.ico.plus').text+soup.select('.rate_info span.blind')[2].string))
        else :
            stock.setdefault("변동률",[]).append(float(soup.select_one('.rate_info span.ico.minus').text+soup.select('.rate_info span.blind')[2].string))

        # 전일
        stock.setdefault("전일",[]).append(int(soup.select('.rate_info  span.blind')[3].string.replace(",","")))

        # 고가
        stock.setdefault("고가",[]).append(int(soup.select('.rate_info  span.blind')[4].string.replace(",","")))

        # 거래량
        stock.setdefault("거래량",[]).append(int(soup.select('.rate_info  span.blind')[6].string.replace(",","")))

        # 시가
        stock.setdefault("시가",[]).append(int(soup.select('.rate_info  span.blind')[7].string.replace(",","")))

        # 저가
        stock.setdefault("저가",[]).append(int(soup.select('.rate_info  span.blind')[8].string.replace(",","")))

        # 거래대금
        stock.setdefault("거래대금",[]).append(int(soup.select('.rate_info  span.blind')[9].string.replace(",","")))
    
stock
# df = pd.DataFrame(stock)
# df
# Out:
# {'년월일': ['2024-07-29', '2024-07-29'],
#  '회사명': ['싸이버원', '프레스티지바이오로직스'],
#  '종목코드': ['356890', '334970'],
#  '현재가': [3245, 5440],
#  '변동금액': [25, 40],
#  '변동률': [-0.76, 0.74],
#  '전일': [3270, 5400],
#  '고가': [3305, 5660],
#  '거래량': [32507, 771379],
#  '시가': [3240, 5310],
#  '저가': [3150, 5260],
#  '거래대금': [105, 4254]}

# %%
for i in data['종목코드'][456:458] :
    print(i)
# Out:
# 356890
# 334970

# %% [markdown]
# ### 변동률 +랑 - 같이 찍히게 하기

# %%
# 변동률 +랑 - 같이 찍히게 하기
url = "https://finance.naver.com/item/main.naver?code=247660"

r = requests.get(url)
dataset2 = r.text
soup2 = BeautifulSoup(dataset2, 'lxml')

# print(float(soup2.select_one('.rate_info span.ico.minus').text+soup2.select('.rate_info span.blind')[2].string))
soup2.select('.rate_info span.blind')[2].string
# Out:
# '30.00'

# %%
soup2.select('.rate_info dd')[2].string[-3:]
# Out:
# '플러스'

# %%
soup2.select_one('.rate_info span.ico.plus').text+soup2.select('.rate_info span.blind')[2].string
# Out:
# '+30.00'

# %%
soup2.select_one('.rate_info span.ico.minus').text+soup2.select('.rate_info span.blind')[2].string
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[261], line 1
# ----> 1 soup2.select_one('.rate_info span.ico.minus').text+soup2.select('.rate_info span.blind')[2].string
#
# AttributeError: 'NoneType' object has no attribute 'text'

# %% [markdown]
# ## 반복문 한 바퀴가 돌면 바로 저장하게끔 하는 방법

# %%
import os
import pandas as pd
from datetime import date
from dotenv import load_dotenv
from sqlalchemy import create_engine
import pymysql
import time
import requests
from bs4 import BeautifulSoup
pymysql.install_as_MySQLdb()
load_dotenv(dotenv_path = ".env_db")

def db_connect() :
    # env 파일을 못 읽어서 실행 파일이 오류가 남.
    # engine = create_engine(f"{os.getenv('db')}+{os.getenv('dbtype')}://{os.getenv('id')}:{os.getenv('pw')}@{os.getenv('host')}/{os.getenv('db_name')}")
    engine = create_engine("mysql+pymysql://root:1234@127.0.0.1:3306/korea_stock_info")
    conn = engine.connect()
    return conn

# %%
def stock_info_scraping() :

    # mysql에서 테이블 불러오기
    conn = db_connect()
    data = pd.read_sql('stock_company_info_2024_07_29', con = conn)
    conn.close()

    # db에 저장하는 함수
    def stock_info_to_db(idx,code,df) :
        today = str(date.today()).replace("-", "_")
        conn = db_connect()
        
        df.to_sql(f"{today[:7]}_stock_price_info", con = conn, if_exists = 'append', index = False)
        conn.close()
        
        return print(f'{today}, {idx}, {code}, {"저장완료":<30s}', end = "\r")


    # 전체 종목

    errors = {}
    for idx, code in enumerate(data['종목코드']) :
        stock = {}
        url = f'https://finance.naver.com/item/main.naver?code={code}'
        r = requests.get(url)
        dataset = r.text
        soup = BeautifulSoup(dataset, 'lxml')
        today = str(date.today())
        try : 
            if code[0] in ("U", "S", "J", "H","C") :
                continue
            else :
                # 년월일
                stock.setdefault("년월일", []).append(today)

                # 회사명
                stock.setdefault("회사명",[]).append(soup.select('dl.blind > dd')[1].string.split(" ")[1])

                # 종목코드
                stock.setdefault("종목코드", []).append(f"{code}")

                # 현재가
                stock.setdefault("현재가",[]).append(soup.select('.rate_info  span.blind')[0].string.replace(",",""))

                # 변동금액
                stock.setdefault("변동금액",[]).append(soup.select('.rate_info  span.blind')[1].string.replace(",",""))

                # 변동률
                if soup.select('.rate_info span.blind')[2].string == '0.00' :
                    stock.setdefault("변동률",[]).append(soup.select('.rate_info span.blind')[2].string)
                elif soup.select('.rate_info dd')[2].string[-3:] == "플러스" :
                    stock.setdefault("변동률",[]).append(float(soup.select_one('.rate_info span.ico.plus').text+soup.select('.rate_info span.blind')[2].string))
                else :
                    stock.setdefault("변동률",[]).append(float(soup.select_one('.rate_info span.ico.minus').text+soup.select('.rate_info span.blind')[2].string))

                # 전일
                stock.setdefault("전일",[]).append(soup.select('.rate_info  span.blind')[3].string.replace(",",""))

                # 고가
                stock.setdefault("고가",[]).append(soup.select('.rate_info  span.blind')[4].string.replace(",",""))

                # 거래량
                stock.setdefault("거래량",[]).append(soup.select('.rate_info  span.blind')[6].string.replace(",",""))

                # 시가
                stock.setdefault("시가",[]).append(soup.select('.rate_info  span.blind')[7].string.replace(",",""))

                # 저가
                stock.setdefault("저가",[]).append(soup.select('.rate_info  span.blind')[8].string.replace(",",""))

                # 거래대금
                stock.setdefault("거래대금",[]).append(soup.select('.rate_info  span.blind')[9].string.replace(",",""))
                
                df = pd.DataFrame(stock)
                stock_info_to_db(idx,code,df)

                time.sleep(3)
                print(f'{idx}번째 진행 중',code, end = "\r")
                
        except Exception as e :
            print(e)
            print(r.status_code, f'{idx}번째 진행 중',code)
            errors.setdefault("에러",[]).append(code) # 에러 코드 모음

# %% [markdown]
# ## 실행파일로 만들기 - 자동화

# %% [markdown]
# ### 강사님 버전

# %%
import os
import pandas as pd
import requests
from bs4 import BeautifulSoup as bs
from datetime import date
from dotenv import load_dotenv
from sqlalchemy import create_engine
import pymysql
import time

pymysql.install_as_MySQLdb()
load_dotenv(dotenv_path=".env_db")
# Out:
# True

# %%
today = str(date.today()).replace("-","_")

# %%
today[:7]
# Out:
# '2024_07'

# %%
def db_connect() :
    engine = create_engine(f"{os.getenv('db')}+{os.getenv('dbtype')}://{os.getenv('id')}:{os.getenv('pw')}@{os.getenv('host')}/{os.getenv('db_name')}")
    conn = engine.connect()
    return conn


def stock_info_scraping() :
    # mysql에서 테이블 불러오기
    conn = db_connect()
    data = pd.read_sql('2024_07_29_stock_company_info', con=conn)
    conn.close()



    # 금액에 컴마(,)를 없애는 함수
    def str2int(x):
        x = int(x.replace(",", ""))
        return x

    # DB에 접속해서 저장하는 함수
    def stock_info_to_db(idx, code, df):
        today = str(date.today()).replace("-","_")
        conn = db_connect()

        engine = create_engine(f"{os.getenv('db')}+{os.getenv('dbtype')}://{os.getenv('id')}:{os.getenv('pw')}@{os.getenv('host')}/{os.getenv('database')}")
        conn = engine.connect()
        df.to_sql(f"{today[:7]}_stock_price_info", con=conn, if_exists='append', index=False)
        conn.close()

        return print(f"{today}, {idx}, {code}, {'저장완료':<30s}", end="\r")

    # 전체 페이지
    errors = {}
    for idx, (company, code) in enumerate(zip(data['회사명'], data['종목코드'])):
        stock_price_detail = {}
        url = f"https://finance.naver.com/item/main.naver?code={code}" 
        try:
            r = requests.get(url)
            print(r.status_code, f"{idx+1}/{len(data['종목코드'])} 수집중                    ", end="\r")
            soup = bs(r.text, 'lxml')
            # 가격
            price = int((soup.select_one(".today").text).strip("\n").split("\n")[1].replace(",", ""))
            # 변동금액
            price_change = int((soup.select_one(".today").text).strip("\n").split("\n")[9].replace(",", ""))
            # 변화율
            rate_of_change = float(((soup.select_one(".today").text).strip("\n").split("\n")[13]+(soup.select_one(".today").text).strip("\n").split("\n")[15]).replace("%",""))
            stock_price_detail.setdefault('수집일', []).append(str(date.today()))
            stock_price_detail.setdefault('회사명', []).append(company)
            stock_price_detail.setdefault('종목코드', []).append(code)
            stock_price_detail.setdefault('현재가', []).append(price)
            stock_price_detail.setdefault('변동금액', []).append(price_chage)
            stock_price_detail.setdefault('변화율', []).append(rate_of_chage)
            table = soup.select_one(".no_info")
            for tr in table.select("tr"):
                for td in tr.select('td'):
                    stock_price_detail.setdefault(td.select_one('span').text, []).append(str2int(td.select_one("span.blind").text))
            df = pd.DataFrame(stock_price_detail)
            stock_info_to_db(idx, code, df)
            time.sleep(5)
        except Exception as e:
            print(e)
            print(r.status_code, f"{idx+1}/{len(data['종목코드'])} 수집중 에러", end="\r")
            errors.setdefault("에러", []).append(code)  # 에러난 코드들 모음
        
stock_price_detail
