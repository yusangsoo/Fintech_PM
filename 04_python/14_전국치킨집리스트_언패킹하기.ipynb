# %%
with open("전국치킨집리스트.json", "r", encoding="utf-8") as f :
    chicken = f.read()
chicken[:10]
# Out:
# '[{"header"'

# %%
chicken[:10]
# Out:
# '[{"header"'

# %%
import json

# %%
data = json.loads(chicken)
print(len(data))
# Out:
# 37

# %%
data[0]
# Out:
# {'header': {'description': '소상공인시장진흥공단 주요상권내 상가업소정보',
#   'columns': ['상가업소번호',
#    '상호명',
#    '지점명',
#    '상권업종대분류코드',
#    '상권업종대분류명',
#    '상권업종중분류코드',
#    '상권업종중분류명',
#    '상권업종소분류코드',
#    '상권업종소분류명',
#    '표준산업분류코드',
#    '표준산업분류명',
#    '시도코드',
#    '시도명',
#    '시군구코드',
#    '시군구명',
#    '행정동코드',
#    '행정동명',
#    '법정동코드',
#    '법정동명',
#    'PNU코드',
#    '대지구분코드',
#    '대지구분명',
#    '지번본번지',
#    '지번부번지',
#    '지번주소',
#    '도로명코드',
#    '도로명',
#    '건물본번지',
#    '건물부번지',
#    '건물관리번호',
#    '건물명',
#    '도로명주소',
#    '구우편번호',
#    '신우편번호',
#    '동정보',
#    '층정보',
#    '호정보',
#    '경도',
#    '위도'],
#   'stdrYm': '202206',
#   'resultCode': '00',
#   'resultMsg': 'NORMAL SERVICE'},
#  'body': {'items': [{'bizesId': '10027626',
#     'bizesNm': '장모님치킨가창점',
#     'brchNm': '가창점',
#     'indsLclsCd': 'Q',
#     'indsLclsNm': '음식',
#     'indsMclsCd': 'Q05',
#     'indsMclsNm': '닭/오리요리',
#     'indsSclsCd': 'Q05A08',
#     'indsSclsNm': '후라이드/양념치킨',
#     'ksicCd': 'I56193',
# ...

# %%
len(data[0]['body']['items'])
# Out:
# 1000

# %%
data[0]['body']['items'][0]
# Out:
# {'bizesId': '10027626',
#  'bizesNm': '장모님치킨가창점',
#  'brchNm': '가창점',
#  'indsLclsCd': 'Q',
#  'indsLclsNm': '음식',
#  'indsMclsCd': 'Q05',
#  'indsMclsNm': '닭/오리요리',
#  'indsSclsCd': 'Q05A08',
#  'indsSclsNm': '후라이드/양념치킨',
#  'ksicCd': 'I56193',
#  'ksicNm': '치킨 전문점',
#  'ctprvnCd': '27',
#  'ctprvnNm': '대구광역시',
#  'signguCd': '27710',
#  'signguNm': '달성군',
#  'adongCd': '2771031000',
#  'adongNm': '가창면',
#  'ldongCd': '2771031024',
#  'ldongNm': '가창면',
#  'lnoCd': '2771031024101200001',
#  'plotSctCd': '1',
#  'plotSctNm': '대지',
#  'lnoMnno': 120,
#  'lnoSlno': 1,
#  'lnoAdr': '대구광역시 달성군 가창면 냉천리 120-1',
#  'rdnmCd': '277103148001',
#  'rdnm': '대구광역시 달성군 가창면 가창동로',
#  'bldMnno': 6,
#  'bldSlno': '',
#  'bldMngNo': '2771031024101200004036858',
#  'bldNm': '',
#  'rdnmAdr': '대구광역시 달성군 가창면 가창동로 6',
#  'oldZipcd': '711861',
#  'newZipcd': '42938',
#  'dongNo': '',
#  'flrNo': '1',
#  'hoNo': '',
#  'lon': 128.644458591419,
#  'lat': 35.7826625402814}

# %%
value_list = []
for i in key :
    for j in data[0]['body']['items'][i] :
        print(i,j)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[42], line 3
#       1 value_list = []
#       2 for i in key :
# ----> 3     for j in data[0]['body']['items'][i] :
#       4         print(i,j)
#
# TypeError: list indices must be integers or slices, not str

# %%
data[0]['body']['items'][0:3]
# Out:
# [{'bizesId': '10027626',
#   'bizesNm': '장모님치킨가창점',
#   'brchNm': '가창점',
#   'indsLclsCd': 'Q',
#   'indsLclsNm': '음식',
#   'indsMclsCd': 'Q05',
#   'indsMclsNm': '닭/오리요리',
#   'indsSclsCd': 'Q05A08',
#   'indsSclsNm': '후라이드/양념치킨',
#   'ksicCd': 'I56193',
#   'ksicNm': '치킨 전문점',
#   'ctprvnCd': '27',
#   'ctprvnNm': '대구광역시',
#   'signguCd': '27710',
#   'signguNm': '달성군',
#   'adongCd': '2771031000',
#   'adongNm': '가창면',
#   'ldongCd': '2771031024',
#   'ldongNm': '가창면',
#   'lnoCd': '2771031024101200001',
#   'plotSctCd': '1',
#   'plotSctNm': '대지',
#   'lnoMnno': 120,
#   'lnoSlno': 1,
#   'lnoAdr': '대구광역시 달성군 가창면 냉천리 120-1',
#   'rdnmCd': '277103148001',
#   'rdnm': '대구광역시 달성군 가창면 가창동로',
#   'bldMnno': 6,
#   'bldSlno': '',
#   'bldMngNo': '2771031024101200004036858',
#   'bldNm': '',
#   'rdnmAdr': '대구광역시 달성군 가창면 가창동로 6',
#   'oldZipcd': '711861',
#   'newZipcd': '42938',
#   'dongNo': '',
#   'flrNo': '1',
#   'hoNo': '',
#   'lon': 128.644458591419,
# ...

# %%
key = []

# %%
result = {}

for item in data[0]['body']['items'] :
    for key, value in item.items() :
        if key not in result :
            result[key] = []
        result[key].append(value)
        
print(result)
# Out:
# {'bizesId': ['10027626', '10098244', '10099459', '10136167', '10136346', '10150151', '10186527', '10208331', '10208355', '10208360', '10231561', '10242205', '10274423', '10398264', '10407416', '10423599', '10446382', '10482089', '10623611', '10663586', '10797221', '10843494', '10849818', '10862582', '10863924', '10872598', '10910446', '10915111', '10935002', '10944198', '10944940', '10983804', '10991930', '11040258', '11047099', '11049106', '11061070', '11128733', '11157227', '11232463', '11253800', '11278610', '11287532', '11301000', '11306589', '11376111', '11378644', '11382583', '11427664', '11434268', '11447247', '11448883', '11449025', '11454601', '11458090', '11459406', '11482381', '11483687', '11484700', '11498882', '11507437', '11520493', '11524244', '11524893', '11529037', '11532764', '11541687', '11547449', '11547684', '11552444', '11569592', '11572236', '11576384', '11580865', '11582307', '11589218', '11598361', '11604910', '11619528', '11620833', '11639762', '11695952', '
# ...

# %%
result['bizesId'][:10]
# Out:
# ['10027626',
#  '10098244',
#  '10099459',
#  '10136167',
#  '10136346',
#  '10150151',
#  '10186527',
#  '10208331',
#  '10208355',
#  '10208360']

# %%
print(len(result))
# Out:
# 39

# %%
list(data[0]['body']['items'][0].values())
# Out:
# ['10027626',
#  '장모님치킨가창점',
#  '가창점',
#  'Q',
#  '음식',
#  'Q05',
#  '닭/오리요리',
#  'Q05A08',
#  '후라이드/양념치킨',
#  'I56193',
#  '치킨 전문점',
#  '27',
#  '대구광역시',
#  '27710',
#  '달성군',
#  '2771031000',
#  '가창면',
#  '2771031024',
#  '가창면',
#  '2771031024101200001',
#  '1',
#  '대지',
#  120,
#  1,
#  '대구광역시 달성군 가창면 냉천리 120-1',
#  '277103148001',
#  '대구광역시 달성군 가창면 가창동로',
#  6,
#  '',
#  '2771031024101200004036858',
#  '',
#  '대구광역시 달성군 가창면 가창동로 6',
#  '711861',
#  '42938',
#  '',
#  '1',
#  '',
#  128.644458591419,
#  35.7826625402814]

# %%
# 실패한 거
for key in data[0]['body']['items'][0] :
    for i in data[0]['body']['items'][0][key] :
        print(key, i)
# Out:
# bizesId 1
# bizesId 0
# bizesId 0
# bizesId 2
# bizesId 7
# bizesId 6
# bizesId 2
# bizesId 6
# bizesNm 장
# bizesNm 모
# bizesNm 님
# bizesNm 치
# bizesNm 킨
# bizesNm 가
# bizesNm 창
# bizesNm 점
# brchNm 가
# brchNm 창
# brchNm 점
# indsLclsCd Q
# indsLclsNm 음
# indsLclsNm 식
# indsMclsCd Q
# indsMclsCd 0
# indsMclsCd 5
# indsMclsNm 닭
# indsMclsNm /
# indsMclsNm 오
# indsMclsNm 리
# indsMclsNm 요
# indsMclsNm 리
# indsSclsCd Q
# indsSclsCd 0
# indsSclsCd 5
# indsSclsCd A
# indsSclsCd 0
# indsSclsCd 8
# indsSclsNm 후
# indsSclsNm 라
# indsSclsNm 이
# indsSclsNm 드
# indsSclsNm /
# indsSclsNm 양
# indsSclsNm 념
# indsSclsNm 치
# indsSclsNm 킨
# ksicCd I
# ksicCd 5
# ksicCd 6
# ksicCd 1
# ksicCd 9
# ksicCd 3
# ksicNm 치
# ksicNm 킨
# ksicNm
# ksicNm 전
# ksicNm 문
# ksicNm 점
# ctprvnCd 2
# ctprvnCd 7
# ctprvnNm 대
# ctprvnNm 구
# ctprvnNm 광
# ctprvnNm 역
# ctprvnNm 시
# signguCd 2
# signguCd 7
# signguCd 7
# signguCd 1
# signguCd 0
# signguNm 달
# signguNm 성
# signguNm 군
# adongCd 2
# adongCd 7
# adongCd 7
# ...

# %%
type(data[0]['body']['items'][0])
# Out:
# dict

# %%
data[0]['body']['items'][0]
# Out:
# {'bizesId': '10027626',
#  'bizesNm': '장모님치킨가창점',
#  'brchNm': '가창점',
#  'indsLclsCd': 'Q',
#  'indsLclsNm': '음식',
#  'indsMclsCd': 'Q05',
#  'indsMclsNm': '닭/오리요리',
#  'indsSclsCd': 'Q05A08',
#  'indsSclsNm': '후라이드/양념치킨',
#  'ksicCd': 'I56193',
#  'ksicNm': '치킨 전문점',
#  'ctprvnCd': '27',
#  'ctprvnNm': '대구광역시',
#  'signguCd': '27710',
#  'signguNm': '달성군',
#  'adongCd': '2771031000',
#  'adongNm': '가창면',
#  'ldongCd': '2771031024',
#  'ldongNm': '가창면',
#  'lnoCd': '2771031024101200001',
#  'plotSctCd': '1',
#  'plotSctNm': '대지',
#  'lnoMnno': 120,
#  'lnoSlno': 1,
#  'lnoAdr': '대구광역시 달성군 가창면 냉천리 120-1',
#  'rdnmCd': '277103148001',
#  'rdnm': '대구광역시 달성군 가창면 가창동로',
#  'bldMnno': 6,
#  'bldSlno': '',
#  'bldMngNo': '2771031024101200004036858',
#  'bldNm': '',
#  'rdnmAdr': '대구광역시 달성군 가창면 가창동로 6',
#  'oldZipcd': '711861',
#  'newZipcd': '42938',
#  'dongNo': '',
#  'flrNo': '1',
#  'hoNo': '',
#  'lon': 128.644458591419,
#  'lat': 35.7826625402814}

# %%
# 첫번째 페이지 딕셔너리 풀고 리스트 만들어서 딕셔너리화
dict = {}
val_list = []
for key in data[0]['body']['items'][0] :
    dict[key] = []
    for value in data[0]['body']['items'] :
        dict[key].append(value[key])
#         print(key, value[key])
dict
# Out:
# {'bizesId': ['10027626',
#   '10098244',
#   '10099459',
#   '10136167',
#   '10136346',
#   '10150151',
#   '10186527',
#   '10208331',
#   '10208355',
#   '10208360',
#   '10231561',
#   '10242205',
#   '10274423',
#   '10398264',
#   '10407416',
#   '10423599',
#   '10446382',
#   '10482089',
#   '10623611',
#   '10663586',
#   '10797221',
#   '10843494',
#   '10849818',
#   '10862582',
#   '10863924',
#   '10872598',
#   '10910446',
#   '10915111',
#   '10935002',
#   '10944198',
#   '10944940',
#   '10983804',
#   '10991930',
#   '11040258',
#   '11047099',
#   '11049106',
#   '11061070',
#   '11128733',
#   '11157227',
#   '11232463',
#   '11253800',
#   '11278610',
#   '11287532',
#   '11301000',
#   '11306589',
#   '11376111',
#   '11378644',
#   '11382583',
#   '11427664',
#   '11434268',
#   '11447247',
#   '11448883',
#   '11449025',
#   '11454601',
#   '11458090',
#   '11459406',
#   '11482381',
#   '11483687',
#   '11484700',
#   '11498882',
#   '11507437',
# ...

# %%
len(dict['bizesId'])
# Out:
# 1000

# %%
# 전체 페이지 작업
dict = {}
for i in range(len(data)) :
    for key in data[0]['body']['items'][0] :
        dict[key] = []
        for value in data[i]['body']['items'] :
            dict[key].append(value[key])
dict['bizesId']
# Out:
# ['9148230',
#  '9149048',
#  '9150436',
#  '9150630',
#  '9150653',
#  '9150712',
#  '9150739',
#  '9150740',
#  '9150749',
#  '9154323',
#  '9169179',
#  '9169194',
#  '9169255',
#  '9169273',
#  '9169284',
#  '9169297',
#  '9169321',
#  '9169350',
#  '9169364',
#  '9169381',
#  '9169400',
#  '9169427',
#  '9169436',
#  '9169456',
#  '9169502',
#  '9170568',
#  '9170590',
#  '9171033',
#  '9172837',
#  '9181809',
#  '9185362',
#  '9185548',
#  '9185881',
#  '9221648',
#  '9234617',
#  '9284085',
#  '9320659',
#  '9320717',
#  '9363787',
#  '9364241',
#  '9369015',
#  '9369026',
#  '9369188',
#  '9380937',
#  '9384389',
#  '9414434',
#  '9420401',
#  '9428226',
#  '9487977',
#  '9487986',
#  '9522182',
#  '9533493',
#  '9543241',
#  '9643952',
#  '9662278',
#  '9662303',
#  '9710457',
#  '9749977',
#  '9767348',
#  '9829515',
#  '9851302',
#  '9867543',
#  '9918905',
#  '9967953']

# %%
# 전체 페이지 작업
dict = {}
for i in range(len(data)) :
    for key in data[i]['body']['items'][0] :
        if key not in dict :
            dict[key] = []
        for value in data[i]['body']['items'] :
            dict[key].append(value[key])
len(dict['bizesId'])
# Out:
# 36064

# %%
# !pip install pandas

# %%
import pandas as pd

# %%
# json_normalize()함수를 사용하면 키와 밸류 형태의 딕셔너리를 키와 해당 밸류들의 리스트 형태인 딕셔너리로 만들어줌
df = pd.json_normalize(item['body']['items'])
df
# Out:
#     bizesId    bizesNm brchNm indsLclsCd indsLclsNm indsMclsCd indsMclsNm  \
# 0   9148230      맛꼬방치킨  남원1호점          Q         음식        Q05     닭/오리요리
# 1   9149048      맛있는파닭                 Q         음식        Q05     닭/오리요리
# 2   9150436       맥땡치킨                 Q         음식        Q05     닭/오리요리
# 3   9150630   맥시카나양념통닭                 Q         음식        Q05     닭/오리요리
# 4   9150653      멕시칸치킨                 Q         음식        Q05     닭/오리요리
# ..      ...        ...    ...        ...        ...        ...        ...
# 59  9829515       아리치킨                 Q         음식        Q05     닭/오리요리
# 60  9851302       애니치킨                 Q         음식        Q05     닭/오리요리
# 61  9867543      에디슨치킨                 Q         음식        Q05     닭/오리요리
# 62  9918905  오븐에꾸운닭장유점    장유점          Q         음식        Q05     닭/오리요리
# 63  9967953       웰빙치킨                 Q         음식        Q05     닭/오리요리
#
#    indsSclsCd indsSclsNm  ksicCd  ...                   bldMngNo       bldNm  \
# ...

# %%
result = pd.DataFrame()
for item in data :
    temp = pd.json_normalize(item['body']['items'])
    result = pd.concat([result,temp])
result
# Out:
#      bizesId    bizesNm brchNm indsLclsCd indsLclsNm indsMclsCd indsMclsNm  \
# 0   10027626   장모님치킨가창점    가창점          Q         음식        Q05     닭/오리요리
# 1   10098244     짱구피자치킨                 Q         음식        Q05     닭/오리요리
# 2   10099459       쭈노치킨                 Q         음식        Q05     닭/오리요리
# 3   10136167       치킨뱅이                 Q         음식        Q05     닭/오리요리
# 4   10136346    치킨월드율량점    율량점          Q         음식        Q05     닭/오리요리
# ..       ...        ...    ...        ...        ...        ...        ...
# 59   9829515       아리치킨                 Q         음식        Q05     닭/오리요리
# 60   9851302       애니치킨                 Q         음식        Q05     닭/오리요리
# 61   9867543      에디슨치킨                 Q         음식        Q05     닭/오리요리
# 62   9918905  오븐에꾸운닭장유점    장유점          Q         음식        Q05     닭/오리요리
# 63   9967953       웰빙치킨                 Q         음식        Q05     닭/오리요리
#
# ...

# %%
result.to_csv('chicken_list.csv', encoding = 'cp949')

# %%
df['bizesNm'].apply(lambda x: x + '$$')
# Out:
# 0        장모님치킨가창점$$
# 1          짱구피자치킨$$
# 2            쭈노치킨$$
# 3            치킨뱅이$$
# 4         치킨월드율량점$$
#            ...
# 995       두두두마리치킨$$
# 996      호식이두마리치킨$$
# 997         또봉이치킨$$
# 998    투마리치킨하늘도시점$$
# 999          노랑통닭$$
# Name: bizesNm, Length: 1000, dtype: object

# %%
df2['bizesNm']
# Out:
# 0         맛꼬방치킨
# 1         맛있는파닭
# 2          맥땡치킨
# 3      맥시카나양념통닭
# 4         멕시칸치킨
#         ...
# 59         아리치킨
# 60         애니치킨
# 61        에디슨치킨
# 62    오븐에꾸운닭장유점
# 63         웰빙치킨
# Name: bizesNm, Length: 64, dtype: object

# %%
df2 = pd.DataFrame(dict)
df2
# Out:
#     bizesId    bizesNm brchNm indsLclsCd indsLclsNm indsMclsCd indsMclsNm  \
# 0   9148230      맛꼬방치킨  남원1호점          Q         음식        Q05     닭/오리요리
# 1   9149048      맛있는파닭                 Q         음식        Q05     닭/오리요리
# 2   9150436       맥땡치킨                 Q         음식        Q05     닭/오리요리
# 3   9150630   맥시카나양념통닭                 Q         음식        Q05     닭/오리요리
# 4   9150653      멕시칸치킨                 Q         음식        Q05     닭/오리요리
# ..      ...        ...    ...        ...        ...        ...        ...
# 59  9829515       아리치킨                 Q         음식        Q05     닭/오리요리
# 60  9851302       애니치킨                 Q         음식        Q05     닭/오리요리
# 61  9867543      에디슨치킨                 Q         음식        Q05     닭/오리요리
# 62  9918905  오븐에꾸운닭장유점    장유점          Q         음식        Q05     닭/오리요리
# 63  9967953       웰빙치킨                 Q         음식        Q05     닭/오리요리
#
#    indsSclsCd indsSclsNm  ksicCd  ...                   bldMngNo       bldNm  \
# ...
